# %% [markdown]
# # 1. Import and Checks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading Datsets**
#
# **Loading 'listings_viz' Datset**

# %%
listings_viz = pd.read_csv(r"C:\Users\Ellen\Desktop\RevenueAI Datasets\listings_viz.csv", encoding_errors='ignore')

# %%
listings_viz
# Out:
#                         id                                               name  \
# 0                    18674    Huge flat for 8 people close to Sagrada Familia
# 1                    23197  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2                    32711                   Sagrada Familia area - Còrsega 1
# 3                    34241   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4                    34981               VIDRE HOME PLAZA REAL on LAS RAMBLAS
# ...                    ...                                                ...
# 19417  1366108822123777508                                 Habitacion Privada
# 19418  1366453124999573764                    Cozy Double Room in City Center
# 19419  1366459989694212599                       140. Poble Sec Ent Apartment
# 19420  1366500461965716620               Big Room with Work Desk - RDL0520003
# 19421  1366501139971684620      Your Boutique Mediterranean Stay in Barcelona
#
#          host_id         host_name neighbourhood_group  \
# 0          71615     Mireia  Maria            Eixample
# 1          90417    Etain (Marnie)          Sant Martí
# 2         135703              Nick              Gràcia
# 3          73163            Andres        Ciutat Vella
# 4          73163            Andres        Ciutat Vella
# ...          ...               ...                 ...
# 19417  413160011   Loucie And John              Gràcia
# 19418  534870364              Juan            Eixample
# 19419     396363  Alcam Apartments      Sants-Montjuïc
# 19420  518888520             David            Eixample
# 19421  124887626               Ana            Eixample
#
#                             neighbourhood   latitude  longitude  \
# 0                      la Sagrada Família  41.405560   2.172620
# 1                   el Besòs i el Maresme  41.412432   2.219750
# 2      el Camp d'en Grassot i Gràcia Nova  41.405660   2.170150
# 3                          el Barri Gòtic  41.380620   2.175170
# 4                          el Barri Gòtic  41.379780   2.176230
# ...                                   ...        ...        ...
# 19417                   la Vila de Gràcia  41.399074   2.159820
# 19418              la Dreta de l'Eixample  41.391440   2.176490
# 19419                        el Poble Sec  41.371550   2.159870
# 19420              la Dreta de l'Eixample  41.392220   2.168250
# 19421                  la Sagrada Família  41.404897   2.180792
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Entire home/apt  179.0               1                 45  2024-09-16
# 1      Entire home/apt  251.0               3                 82  2025-01-03
# 2      Entire home/apt  104.0               1                143  2025-03-04
# 3      Entire home/apt  157.0              31                 25  2024-11-05
# 4      Entire home/apt  401.0               5                256  2025-02-02
# ...                ...    ...             ...                ...         ...
# 19417     Private room   27.0              31                  0         NaN
# 19418     Private room   60.0               1                  0         NaN
# 19419  Entire home/apt  103.0              33                  0         NaN
# 19420     Private room   31.0              32                  0         NaN
# 19421  Entire home/apt  307.0               2                  1  2025-03-05
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.31                              29               147
# 1                   0.48                               1                 0
# 2                   0.86                               3               107
# 3                   0.14                               3               327
# 4                   1.46                               3               191
# ...                  ...                             ...               ...
# 19417                NaN                               8               348
# 19418                NaN                               6                 1
# 19419                NaN                              75               359
# 19420                NaN                              98               278
# 19421               1.00                               1                51
#
#        number_of_reviews_ltm      license
# 0                          5  HUTB-002062
# 1                          8   HUTB005057
# 2                         31  HUTB-001722
# 3                         15       Exempt
# 4                         34  HUTB-150671
# ...                      ...          ...
# 19417                      0       Exempt
# 19418                      0       Exempt
# 19419                      0          NaN
# 19420                      0          NaN
# 19421                      1  HUTB-003778
#
# [19422 rows x 18 columns]

# %% [markdown]
# **Loading 'listings' Datset**

# %%
listings = pd.read_csv(r"C:\Users\Ellen\Desktop\RevenueAI Datasets\listings.csv", encoding_errors='ignore')

# %%
listings
# Out:
#                         id                                       listing_url  \
# 0                    18674                https://www.airbnb.com/rooms/18674
# 1                    23197                https://www.airbnb.com/rooms/23197
# 2                    32711                https://www.airbnb.com/rooms/32711
# 3                    34241                https://www.airbnb.com/rooms/34241
# 4                    34981                https://www.airbnb.com/rooms/34981
# ...                    ...                                               ...
# 19417  1366108822123777508  https://www.airbnb.com/rooms/1366108822123777508
# 19418  1366453124999573764  https://www.airbnb.com/rooms/1366453124999573764
# 19419  1366459989694212599  https://www.airbnb.com/rooms/1366459989694212599
# 19420  1366500461965716620  https://www.airbnb.com/rooms/1366500461965716620
# 19421  1366501139971684620  https://www.airbnb.com/rooms/1366501139971684620
#
#             scrape_id last_scraped       source  \
# 0      20250305023237   2025-03-06  city scrape
# 1      20250305023237   2025-03-07  city scrape
# 2      20250305023237   2025-03-06  city scrape
# 3      20250305023237   2025-03-05  city scrape
# 4      20250305023237   2025-03-05  city scrape
# ...               ...          ...          ...
# 19417  20250305023237   2025-03-06  city scrape
# 19418  20250305023237   2025-03-11  city scrape
# 19419  20250305023237   2025-03-07  city scrape
# 19420  20250305023237   2025-03-07  city scrape
# 19421  20250305023237   2025-03-10  city scrape
#
#                                                     name  \
# 0        Huge flat for 8 people close to Sagrada Familia
# 1      Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2                       Sagrada Familia area - Còrsega 1
# 3       Stylish Top Floor Apartment - Ramblas Plaza Real
# 4                   VIDRE HOME PLAZA REAL on LAS RAMBLAS
# ...                                                  ...
# 19417                                 Habitacion Privada
# 19418                    Cozy Double Room in City Center
# 19419                       140. Poble Sec Ent Apartment
# 19420               Big Room with Work Desk - RDL0520003
# 19421      Your Boutique Mediterranean Stay in Barcelona
#
#                                              description  \
# 0      110m2 apartment to rent in Barcelona. Located ...
# 1      Beautiful and Spacious Apartment with Large Te...
# 2      A lovely two bedroom apartment only 250 m from...
# 3      Located in close proximity to Plaza Real and L...
# 4      Spacious apartment for large families or group...
# ...                                                  ...
# 19417  SHARED FLOOR OF 5 ROOMS, cosmopolitan atmosphe...
# 19418  Double room with double bed on shared floor, i...
# 19419  Apartment with 2 bedrooms and 1 bathroom in th...
# 19420  Newly renovated apartment with five bedrooms a...
# 19421  Your Boutique Mediterranean Stay | 6 Min to Sa...
#
#                                    neighborhood_overview  \
# 0      Apartment in Barcelona located in the heart of...
# 1      Strategically located in the Parc del Fòrum, a...
# 2      What's nearby  <br />This apartment is located...
# 3                                                    NaN
# 4      Located in Ciutat Vella in the Gothic Quarter,...
# ...                                                  ...
# 19417                                                NaN
# 19418  The area between Urquinaona and Arc de Triomf,...
# 19419                                                NaN
# 19420                                                NaN
# 19421                                                NaN
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/13031453/413c...      71615  ...
# 1      https://a0.muscache.com/pictures/miso/Hosting-...      90417  ...
# 2      https://a0.muscache.com/pictures/357b25e4-f414...     135703  ...
# 3      https://a0.muscache.com/pictures/2437facc-2fe7...      73163  ...
# 4      https://a0.muscache.com/pictures/c4d1723c-e479...      73163  ...
# ...                                                  ...        ...  ...
# 19417  https://a0.muscache.com/pictures/7d0b8e77-7724...  413160011  ...
# 19418  https://a0.muscache.com/pictures/miso/Hosting-...  534870364  ...
# 19419  https://a0.muscache.com/pictures/prohost-api/H...     396363  ...
# 19420  https://a0.muscache.com/pictures/miso/Hosting-...  518888520  ...
# 19421  https://a0.muscache.com/pictures/hosting/Hosti...  124887626  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.70                   4.80                4.32
# 1                            4.99                   4.63                4.66
# 2                            4.89                   4.89                4.49
# 3                            4.68                   4.73                4.23
# 4                            4.70                   4.66                4.43
# ...                           ...                    ...                 ...
# 19417                         NaN                    NaN                 NaN
# 19418                         NaN                    NaN                 NaN
# 19419                         NaN                    NaN                 NaN
# 19420                         NaN                    NaN                 NaN
# 19421                        5.00                   5.00                5.00
#
#            license instant_bookable calculated_host_listings_count  \
# 0      HUTB-002062                t                             29
# 1       HUTB005057                f                              1
# 2      HUTB-001722                f                              3
# 3           Exempt                f                              3
# 4      HUTB-150671                f                              3
# ...            ...              ...                            ...
# 19417       Exempt                f                              8
# 19418       Exempt                t                              6
# 19419          NaN                f                             75
# 19420          NaN                f                             98
# 19421  HUTB-003778                f                              1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                              29
# 1                                               1
# 2                                               3
# 3                                               3
# 4                                               3
# ...                                           ...
# 19417                                           0
# 19418                                           0
# 19419                                          75
# 19420                                           8
# 19421                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 19417                                            8
# 19418                                            6
# 19419                                            0
# 19420                                           90
# 19421                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.31
# 1                                               0              0.48
# 2                                               0              0.86
# 3                                               0              0.14
# 4                                               0              1.46
# ...                                           ...               ...
# 19417                                           0               NaN
# 19418                                           0               NaN
# 19419                                           0               NaN
# 19420                                           0               NaN
# 19421                                           0              1.00
#
# [19422 rows x 79 columns]

# %% [markdown]
# **Loading 'listings_viz' Datset**

# %%
reviews_viz = pd.read_csv(r"C:\Users\Ellen\Desktop\RevenueAI Datasets\reviews_viz.csv", encoding_errors='ignore')

# %%
reviews_viz
# Out:
#                  listing_id        date
# 0                     18674  2013-05-27
# 1                     18674  2014-03-02
# 2                     18674  2015-08-04
# 3                     18674  2016-06-20
# 4                     18674  2018-06-18
# ...                     ...         ...
# 965850  1354363590227566368  2025-03-04
# 965851  1354420227523365801  2025-02-21
# 965852  1354420227523365801  2025-02-23
# 965853  1354420227523365801  2025-03-01
# 965854  1355642373805293598  2025-02-15
#
# [965855 rows x 2 columns]

# %% [markdown]
# # Step 2: Data Inspection & Cleaning
# **Handling missing values: 'listings_viz' dataset**

# %%
listings_viz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19422 entries, 0 to 19421
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19422 non-null  int64
#  1   name                            19422 non-null  object
#  2   host_id                         19422 non-null  int64
#  3   host_name                       19415 non-null  object
#  4   neighbourhood_group             19422 non-null  object
#  5   neighbourhood                   19422 non-null  object
#  6   latitude                        19422 non-null  float64
#  7   longitude                       19422 non-null  float64
#  8   room_type                       19422 non-null  object
#  9   price                           15273 non-null  float64
#  10  minimum_nights                  19422 non-null  int64
#  11  number_of_reviews               19422 non-null  int64
#  12  last_review                     14513 non-null  object
#  13  reviews_per_month               14513 non-null  float64
#  14  calculated_host_listings_count  19422 non-null  int64
#  15  availability_365                19422 non-null  int64
#  16  number_of_reviews_ltm           19422 non-null  int64
#  17  license                         13200 non-null  object
# dtypes: float64(4), int64(7), object(7)
# memory usage: 2.7+ MB

# %%
listings_viz.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  1.942200e+04  1.942200e+04  19422.000000  19422.000000  15273.000000
# mean   5.340735e+17  2.011099e+08     41.392127      2.166932    161.542264
# std    5.386541e+17  2.033453e+08      0.014056      0.017663    327.006539
# min    1.867400e+04  3.073000e+03     41.335310      2.085593      8.000000
# 25%    2.738201e+07  1.110253e+07     41.381070      2.156540     65.000000
# 50%    6.010367e+17  1.308027e+08     41.389956      2.167670    117.000000
# 75%    1.078802e+18  3.579465e+08     41.401590      2.177540    181.000000
# max    1.368966e+18  6.801697e+08     41.456377      2.221830  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    19422.000000       19422.000000       14513.000000
# mean        15.329266          49.729945           1.444763
# std         27.679158         105.133092           2.006798
# min          1.000000           0.000000           0.010000
# 25%          1.000000           0.000000           0.200000
# 50%          3.000000           6.000000           0.780000
# 75%         31.000000          48.000000           2.180000
# max       1124.000000        3091.000000          79.120000
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# count                    19422.000000      19422.000000           19422.000000
# mean                        49.529812        161.790907              11.749923
# std                        104.113008        130.780438              24.279234
# min                          1.000000          0.000000               0.000000
# 25%                          2.000000          1.000000               0.000000
# 50%                          7.000000        174.000000               2.000000
# 75%                         34.000000        280.000000              15.000000
# max                        483.000000        365.000000            1239.000000

# %%
# Check missing values
print("Missing values in listings_viz:")
print(listings_viz.isnull().sum().sort_values(ascending=False))
# Out:
# Missing values in listings_viz:
# license                           6222
# last_review                       4909
# reviews_per_month                 4909
# price                             4149
# host_name                            7
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# name                                 0
# minimum_nights                       0
# number_of_reviews                    0
# host_id                              0
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# id                                   0
# dtype: int64

# %%
# Standardize column names
listings_viz.columns = listings_viz.columns.str.strip().str.lower().str.replace(" ", "_")

# Fill reviews_per_month with 0 (assume no reviews = 0 activity)
listings_viz['reviews_per_month'] = listings_viz['reviews_per_month'].fillna(0)

# Impute missing 'price' with the median
price_median = listings_viz['price'].median()
listings_viz['price'] = listings_viz['price'].fillna(price_median)

# Leave license, last_review, and host_name as NaN
print(listings_viz[['license', 'last_review', 'host_name']].isnull().sum())
# Out:
# license        6222
# last_review    4909
# host_name         7
# dtype: int64

# %%
# Check missing values
print("Missing values in listings_viz:")
print(listings_viz.isnull().sum().sort_values(ascending=False))
# Out:
# Missing values in listings_viz:
# license                           6222
# last_review                       4909
# host_name                            7
# minimum_nights                       0
# number_of_reviews_ltm                0
# availability_365                     0
# calculated_host_listings_count       0
# reviews_per_month                    0
# number_of_reviews                    0
# id                                   0
# name                                 0
# room_type                            0
# longitude                            0
# latitude                             0
# neighbourhood                        0
# neighbourhood_group                  0
# host_id                              0
# price                                0
# dtype: int64

# %%
# type casting 
# changing data types 
listings_viz.dtypes

listings_viz['id'] = listings_viz['id'].astype(object)
listings_viz.dtypes

listings_viz['host_id'] = listings_viz['host_id'].astype(object)
listings_viz.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
# Check for duplicate rows
duplicates_listings_viz = listings_viz.duplicated().sum()
print(f"Duplicate rows in listings_viz: {duplicates_listings_viz}")
# Out:
# Duplicate rows in listings_viz: 0

# %% [markdown]
# **Handling missing values: 'listings' dataset**

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19422 entries, 0 to 19421
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            19422 non-null  int64
#  1   listing_url                                   19422 non-null  object
#  2   scrape_id                                     19422 non-null  int64
#  3   last_scraped                                  19422 non-null  object
#  4   source                                        19422 non-null  object
#  5   name                                          19422 non-null  object
#  6   description                                   18676 non-null  object
#  7   neighborhood_overview                         9575 non-null   object
#  8   picture_url                                   19422 non-null  object
#  9   host_id                                       19422 non-null  int64
#  10  host_url                                      19422 non-null  object
#  11  host_name                                     19415 non-null  object
#  12  host_since                                    19415 non-null  object
#  13  host_location                                 14919 non-null  object
#  14  host_about                                    12208 non-null  object
#  15  host_response_time                            16295 non-null  object
#  16  host_response_rate                            16295 non-null  object
#  17  host_acceptance_rate                          16655 non-null  object
#  18  host_is_superhost                             18868 non-null  object
#  19  host_thumbnail_url                            19415 non-null  object
#  20  host_picture_url                              19415 non-null  object
#  21  host_neighbourhood                            9501 non-null   object
#  22  host_listings_count                           19415 non-null  float64
#  23  host_total_listings_count                     19415 non-null  float64
#  24  host_verifications                            19415 non-null  object
#  25  host_has_profile_pic                          19415 non-null  object
#  26  host_identity_verified                        19415 non-null  object
#  27  neighbourhood                                 9575 non-null   object
#  28  neighbourhood_cleansed                        19422 non-null  object
#  29  neighbourhood_group_cleansed                  19422 non-null  object
#  30  latitude                                      19422 non-null  float64
#  31  longitude                                     19422 non-null  float64
#  32  property_type                                 19422 non-null  object
#  33  room_type                                     19422 non-null  object
#  34  accommodates                                  19422 non-null  int64
#  35  bathrooms                                     15280 non-null  float64
#  36  bathrooms_text                                19411 non-null  object
#  37  bedrooms                                      17442 non-null  float64
#  38  beds                                          15214 non-null  float64
#  39  amenities                                     19422 non-null  object
#  40  price                                         15273 non-null  object
#  41  minimum_nights                                19422 non-null  int64
#  42  maximum_nights                                19422 non-null  int64
#  43  minimum_minimum_nights                        19420 non-null  float64
#  44  maximum_minimum_nights                        19420 non-null  float64
#  45  minimum_maximum_nights                        19420 non-null  float64
#  46  maximum_maximum_nights                        19420 non-null  float64
#  47  minimum_nights_avg_ntm                        19420 non-null  float64
#  48  maximum_nights_avg_ntm                        19420 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              18341 non-null  object
#  51  availability_30                               19422 non-null  int64
#  52  availability_60                               19422 non-null  int64
#  53  availability_90                               19422 non-null  int64
#  54  availability_365                              19422 non-null  int64
#  55  calendar_last_scraped                         19422 non-null  object
#  56  number_of_reviews                             19422 non-null  int64
#  57  number_of_reviews_ltm                         19422 non-null  int64
#  58  number_of_reviews_l30d                        19422 non-null  int64
#  59  availability_eoy                              19422 non-null  int64
#  60  number_of_reviews_ly                          19422 non-null  int64
#  61  estimated_occupancy_l365d                     19422 non-null  int64
#  62  estimated_revenue_l365d                       15273 non-null  float64
#  63  first_review                                  14513 non-null  object
#  64  last_review                                   14513 non-null  object
#  65  review_scores_rating                          14513 non-null  float64
#  66  review_scores_accuracy                        14510 non-null  float64
#  67  review_scores_cleanliness                     14511 non-null  float64
#  68  review_scores_checkin                         14509 non-null  float64
#  69  review_scores_communication                   14512 non-null  float64
#  70  review_scores_location                        14510 non-null  float64
#  71  review_scores_value                           14510 non-null  float64
#  72  license                                       13200 non-null  object
#  73  instant_bookable                              19422 non-null  object
#  74  calculated_host_listings_count                19422 non-null  int64
#  75  calculated_host_listings_count_entire_homes   19422 non-null  int64
#  76  calculated_host_listings_count_private_rooms  19422 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   19422 non-null  int64
#  78  reviews_per_month                             14513 non-null  float64
# dtypes: float64(23), int64(20), object(36)
# memory usage: 11.7+ MB

# %%
# Check missing values only for the review_scores_rating column
missing_review_scores = listings['review_scores_rating'].isnull().sum()
print(f"Missing values in review_scores_rating: {missing_review_scores}")
# Out:
# Missing values in review_scores_rating: 4909

# %%
# Check for NaN values in the review_scores_rating column
nan_count = listings['review_scores_rating'].isna().sum()
print(f"Number of NaN values in 'review_scores_rating': {nan_count}")
# Out:
# Number of NaN values in 'review_scores_rating': 4909

# %%
# Check for duplicate rows
duplicates_listings = listings.duplicated().sum()
print(f"Duplicate rows in listings: {duplicates_listings}")
# Out:
# Duplicate rows in listings: 0

# %% [markdown]
# **Handling missing values: 'reviews_viz' dataset**

# %%
reviews_viz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965855 entries, 0 to 965854
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  965855 non-null  int64
#  1   date        965855 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 14.7+ MB

# %%
# Check missing values
print("\nMissing values in reviews_viz:")
print(reviews_viz.isnull().sum().sort_values(ascending=False))
# Out:
# Missing values in reviews_viz:
# listing_id    0
# date          0
# dtype: int64

# %%
# Check for duplicate rows
duplicates_reviews_viz = reviews_viz.duplicated().sum()
print(f"Duplicate rows in reviews_viz: {duplicates_reviews_viz}")
# Out:
# Duplicate rows in reviews_viz: 24759

# %% [markdown]
# # 3. Joining Tables

# %%
# Select only necessary columns
listings_group = listings[['id', 'review_scores_rating']]
reviews_group = reviews_viz[['listing_id', 'date']]

listings_viz = listings_viz.merge(listings_group, how='left', on='id')
listings_viz = listings_viz.merge(reviews_group, how='left', left_on='id', right_on='listing_id')

# Drop the extra join column
listings_viz.drop(columns=['listing_id'], inplace=True)

# %%
listings_viz
# Out:
#                          id                                             name  \
# 0                     18674  Huge flat for 8 people close to Sagrada Familia
# 1                     18674  Huge flat for 8 people close to Sagrada Familia
# 2                     18674  Huge flat for 8 people close to Sagrada Familia
# 3                     18674  Huge flat for 8 people close to Sagrada Familia
# 4                     18674  Huge flat for 8 people close to Sagrada Familia
# ...                     ...                                              ...
# 970759  1366108822123777508                               Habitacion Privada
# 970760  1366453124999573764                  Cozy Double Room in City Center
# 970761  1366459989694212599                     140. Poble Sec Ent Apartment
# 970762  1366500461965716620             Big Room with Work Desk - RDL0520003
# 970763  1366501139971684620    Your Boutique Mediterranean Stay in Barcelona
#
#           host_id         host_name neighbourhood_group  \
# 0           71615     Mireia  Maria            Eixample
# 1           71615     Mireia  Maria            Eixample
# 2           71615     Mireia  Maria            Eixample
# 3           71615     Mireia  Maria            Eixample
# 4           71615     Mireia  Maria            Eixample
# ...           ...               ...                 ...
# 970759  413160011   Loucie And John              Gràcia
# 970760  534870364              Juan            Eixample
# 970761     396363  Alcam Apartments      Sants-Montjuïc
# 970762  518888520             David            Eixample
# 970763  124887626               Ana            Eixample
#
#                  neighbourhood   latitude  longitude        room_type  price  \
# 0           la Sagrada Família  41.405560   2.172620  Entire home/apt  179.0
# 1           la Sagrada Família  41.405560   2.172620  Entire home/apt  179.0
# 2           la Sagrada Família  41.405560   2.172620  Entire home/apt  179.0
# 3           la Sagrada Família  41.405560   2.172620  Entire home/apt  179.0
# 4           la Sagrada Família  41.405560   2.172620  Entire home/apt  179.0
# ...                        ...        ...        ...              ...    ...
# 970759       la Vila de Gràcia  41.399074   2.159820     Private room   27.0
# 970760  la Dreta de l'Eixample  41.391440   2.176490     Private room   60.0
# 970761            el Poble Sec  41.371550   2.159870  Entire home/apt  103.0
# 970762  la Dreta de l'Eixample  41.392220   2.168250     Private room   31.0
# 970763      la Sagrada Família  41.404897   2.180792  Entire home/apt  307.0
#
#         minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                    1                 45  2024-09-16               0.31
# 1                    1                 45  2024-09-16               0.31
# 2                    1                 45  2024-09-16               0.31
# 3                    1                 45  2024-09-16               0.31
# 4                    1                 45  2024-09-16               0.31
# ...                ...                ...         ...                ...
# 970759              31                  0         NaN               0.00
# 970760               1                  0         NaN               0.00
# 970761              33                  0         NaN               0.00
# 970762              32                  0         NaN               0.00
# 970763               2                  1  2025-03-05               1.00
#
#         calculated_host_listings_count  availability_365  \
# 0                                   29               147
# 1                                   29               147
# 2                                   29               147
# 3                                   29               147
# 4                                   29               147
# ...                                ...               ...
# 970759                               8               348
# 970760                               6                 1
# 970761                              75               359
# 970762                              98               278
# 970763                               1                51
#
#         number_of_reviews_ltm      license  review_scores_rating        date
# 0                           5  HUTB-002062                  4.39  2013-05-27
# 1                           5  HUTB-002062                  4.39  2014-03-02
# 2                           5  HUTB-002062                  4.39  2015-08-04
# 3                           5  HUTB-002062                  4.39  2016-06-20
# 4                           5  HUTB-002062                  4.39  2018-06-18
# ...                       ...          ...                   ...         ...
# 970759                      0       Exempt                   NaN         NaN
# 970760                      0       Exempt                   NaN         NaN
# 970761                      0          NaN                   NaN         NaN
# 970762                      0          NaN                   NaN         NaN
# 970763                      1  HUTB-003778                  5.00  2025-03-05
#
# [970764 rows x 20 columns]

# %%
listings_viz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970764 entries, 0 to 970763
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              970764 non-null  object
#  1   name                            970764 non-null  object
#  2   host_id                         970764 non-null  object
#  3   host_name                       970243 non-null  object
#  4   neighbourhood_group             970764 non-null  object
#  5   neighbourhood                   970764 non-null  object
#  6   latitude                        970764 non-null  float64
#  7   longitude                       970764 non-null  float64
#  8   room_type                       970764 non-null  object
#  9   price                           970764 non-null  float64
#  10  minimum_nights                  970764 non-null  int64
#  11  number_of_reviews               970764 non-null  int64
#  12  last_review                     965855 non-null  object
#  13  reviews_per_month               970764 non-null  float64
#  14  calculated_host_listings_count  970764 non-null  int64
#  15  availability_365                970764 non-null  int64
#  16  number_of_reviews_ltm           970764 non-null  int64
#  17  license                         909904 non-null  object
#  18  review_scores_rating            965855 non-null  float64
#  19  date                            965855 non-null  object
# dtypes: float64(5), int64(5), object(10)
# memory usage: 148.1+ MB

# %%
listings_viz.describe()
# Out:
#             latitude      longitude          price  minimum_nights  \
# count  970764.000000  970764.000000  970764.000000   970764.000000
# mean       41.391781       2.167067     169.524821        5.442391
# std         0.012849       0.016237     132.853599       19.329440
# min        41.335310       2.085593       8.000000        1.000000
# 25%        41.381170       2.158060     116.000000        1.000000
# 50%        41.391068       2.167270     145.000000        2.000000
# 75%        41.401200       2.175900     203.000000        3.000000
# max        41.456377       2.221830   10000.000000     1124.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count      970764.000000      970764.000000                   970764.000000
# mean          270.602939           3.625967                       18.827851
# std           280.130052           5.784310                       43.287185
# min             0.000000           0.000000                        1.000000
# 25%            98.000000           1.610000                        1.000000
# 50%           206.000000           2.620000                        4.000000
# 75%           366.000000           3.800000                       14.000000
# max          3091.000000          79.120000                      483.000000
#
#        availability_365  number_of_reviews_ltm  review_scores_rating
# count     970764.000000          970764.000000         965855.000000
# mean         172.173632              50.101625              4.694793
# std          117.826667              87.706835              0.204434
# min            0.000000               0.000000              1.000000
# 25%           59.000000              19.000000              4.580000
# 50%          190.000000              37.000000              4.730000
# 75%          275.000000              55.000000              4.840000
# max          365.000000            1239.000000              5.000000

# %% [markdown]
# # 4. Data Inspection & Cleaning
# **Handling missing values**

# %%
listings_viz.isnull().sum()

# dropping all missing values rows
listings_viz.dropna(inplace=True)

# data.fillna()
listings_viz.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# review_scores_rating              0
# date                              0
# dtype: int64

# %%
# Check for duplicate rows in the final merged dataset
duplicates_joined = listings_viz.duplicated().sum()
print(f"Duplicate rows in the final joined listings_viz table: {duplicates_joined}")
# Out:
# Duplicate rows in the final joined listings_viz table: 24713

# %%
# Inspect duplicate rows
duplicate_rows = listings_viz[listings_viz.duplicated()]
print(duplicate_rows.head())
# Out:
#          id                              name host_id host_name  \
# 1890  72436  Lugaris Beach Business Apartment  375625    Xavier
# 1895  72436  Lugaris Beach Business Apartment  375625    Xavier
# 1896  72436  Lugaris Beach Business Apartment  375625    Xavier
# 1898  72436  Lugaris Beach Business Apartment  375625    Xavier
# 1899  72436  Lugaris Beach Business Apartment  375625    Xavier
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 1890          Sant Martí   el Poblenou  41.39909    2.20733  Entire home/apt
# 1895          Sant Martí   el Poblenou  41.39909    2.20733  Entire home/apt
# 1896          Sant Martí   el Poblenou  41.39909    2.20733  Entire home/apt
# 1898          Sant Martí   el Poblenou  41.39909    2.20733  Entire home/apt
# 1899          Sant Martí   el Poblenou  41.39909    2.20733  Entire home/apt
#
#       price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 1890  173.0               1                935  2025-02-27               7.28
# 1895  173.0               1                935  2025-02-27               7.28
# 1896  173.0               1                935  2025-02-27               7.28
# 1898  173.0               1                935  2025-02-27               7.28
# 1899  173.0               1                935  2025-02-27               7.28
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 1890                               6               240                    136
# 1895                               6               240                    136
# 1896                               6               240                    136
# 1898                               6               240                    136
# 1899                               6               240                    136
#
#           license  review_scores_rating        date
# 1890  HUTB-000173                  4.73  2018-09-10
# 1895  HUTB-000173                  4.73  2018-10-14
# 1896  HUTB-000173                  4.73  2018-10-14
# 1898  HUTB-000173                  4.73  2018-10-15
# 1899  HUTB-000173                  4.73  2018-10-15

# %%
listing_summary = listings_viz.drop_duplicates(subset='id')

# %%
print(f"Original rows in listings_viz: {len(listings_viz)}")
print(f"Rows after deduplication: {len(listing_summary)}")
# Out:
# Original rows in listings_viz: 907273
# Rows after deduplication: 11083

# %%
listing_summary
# Out:
#                          id  \
# 0                     18674
# 45                    23197
# 127                   32711
# 270                   34241
# 295                   34981
# ...                     ...
# 970689  1360321988927450011
# 970703  1361373593637781974
# 970740  1364579851850890371
# 970752  1365775429128918380
# 970763  1366501139971684620
#
#                                                      name    host_id  \
# 0         Huge flat for 8 people close to Sagrada Familia      71615
# 45      Forum CCIB DeLuxe, Spacious, Large Balcony, relax      90417
# 127                      Sagrada Familia area - Còrsega 1     135703
# 270      Stylish Top Floor Apartment - Ramblas Plaza Real      73163
# 295                  VIDRE HOME PLAZA REAL on LAS RAMBLAS      73163
# ...                                                   ...        ...
# 970689                      Acogedor apartamento céntrico   35069722
# 970703                      Double room in the Best Place  579357044
# 970740                       Barcelona Center DoubleRoom!  539685683
# 970752                        Habitación cerca del centro  278820532
# 970763      Your Boutique Mediterranean Stay in Barcelona  124887626
#
#              host_name neighbourhood_group  \
# 0        Mireia  Maria            Eixample
# 45      Etain (Marnie)          Sant Martí
# 127               Nick              Gràcia
# 270             Andres        Ciutat Vella
# 295             Andres        Ciutat Vella
# ...                ...                 ...
# 970689           Judit      Sants-Montjuïc
# 970703        Cristina          Sant Martí
# 970740         Mikhail            Eixample
# 970752       Francesco            Eixample
# 970763             Ana            Eixample
#
#                              neighbourhood   latitude  longitude  \
# 0                       la Sagrada Família  41.405560   2.172620
# 45                   el Besòs i el Maresme  41.412432   2.219750
# 127     el Camp d'en Grassot i Gràcia Nova  41.405660   2.170150
# 270                         el Barri Gòtic  41.380620   2.175170
# 295                         el Barri Gòtic  41.379780   2.176230
# ...                                    ...        ...        ...
# 970689                        el Poble Sec  41.372603   2.166521
# 970703            Sant Martí de Provençals  41.416420   2.195170
# 970740              la Dreta de l'Eixample  41.398464   2.173269
# 970752      la Nova Esquerra de l'Eixample  41.384940   2.145140
# 970763                  la Sagrada Família  41.404897   2.180792
#
#               room_type  price  minimum_nights  number_of_reviews last_review  \
# 0       Entire home/apt  179.0               1                 45  2024-09-16
# 45      Entire home/apt  251.0               3                 82  2025-01-03
# 127     Entire home/apt  104.0               1                143  2025-03-04
# 270     Entire home/apt  157.0              31                 25  2024-11-05
# 295     Entire home/apt  401.0               5                256  2025-02-02
# ...                 ...    ...             ...                ...         ...
# 970689  Entire home/apt  111.0               2                  1  2025-03-04
# 970703     Private room   74.0               2                  1  2025-03-07
# 970740     Private room   59.0               1                  1  2025-03-03
# 970752     Private room   68.0               1                  1  2025-03-05
# 970763  Entire home/apt  307.0               2                  1  2025-03-05
#
#         reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                    0.31                              29               147
# 45                   0.48                               1                 0
# 127                  0.86                               3               107
# 270                  0.14                               3               327
# 295                  1.46                               3               191
# ...                   ...                             ...               ...
# 970689               1.00                               2               140
# 970703               1.00                              24                82
# 970740               1.00                               4               340
# 970752               1.00                               2               345
# 970763               1.00                               1                51
#
#         number_of_reviews_ltm      license  review_scores_rating        date
# 0                           5  HUTB-002062                  4.39  2013-05-27
# 45                          8   HUTB005057                  4.80  2011-03-15
# 127                        31  HUTB-001722                  4.46  2011-07-17
# 270                        15       Exempt                  4.36  2010-07-10
# 295                        34  HUTB-150671                  4.54  2010-10-03
# ...                       ...          ...                   ...         ...
# 970689                      1  HUTB-011205                  5.00  2025-03-04
# 970703                      1  HUTB-748559                  4.00  2025-03-07
# 970740                      1       Exempt                  5.00  2025-03-03
# 970752                      1       Exempt                  5.00  2025-03-05
# 970763                      1  HUTB-003778                  5.00  2025-03-05
#
# [11083 rows x 20 columns]

# %% [markdown]
# **Additional Join for Data Enrichment**

# %%
# Select only id and revenue column
revenue_data = listings[['id', 'estimated_revenue_l365d', 'bedrooms', 'beds', 'bathrooms']]

# Merge with listing_summary
overall_listings = listing_summary.merge(revenue_data, how='left', on='id')

# %%
overall_listings
# Out:
#                         id                                               name  \
# 0                    18674    Huge flat for 8 people close to Sagrada Familia
# 1                    23197  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2                    32711                   Sagrada Familia area - Còrsega 1
# 3                    34241   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4                    34981               VIDRE HOME PLAZA REAL on LAS RAMBLAS
# ...                    ...                                                ...
# 11078  1360321988927450011                      Acogedor apartamento céntrico
# 11079  1361373593637781974                      Double room in the Best Place
# 11080  1364579851850890371                       Barcelona Center DoubleRoom!
# 11081  1365775429128918380                        Habitación cerca del centro
# 11082  1366501139971684620      Your Boutique Mediterranean Stay in Barcelona
#
#          host_id       host_name neighbourhood_group  \
# 0          71615   Mireia  Maria            Eixample
# 1          90417  Etain (Marnie)          Sant Martí
# 2         135703            Nick              Gràcia
# 3          73163          Andres        Ciutat Vella
# 4          73163          Andres        Ciutat Vella
# ...          ...             ...                 ...
# 11078   35069722           Judit      Sants-Montjuïc
# 11079  579357044        Cristina          Sant Martí
# 11080  539685683         Mikhail            Eixample
# 11081  278820532       Francesco            Eixample
# 11082  124887626             Ana            Eixample
#
#                             neighbourhood   latitude  longitude  \
# 0                      la Sagrada Família  41.405560   2.172620
# 1                   el Besòs i el Maresme  41.412432   2.219750
# 2      el Camp d'en Grassot i Gràcia Nova  41.405660   2.170150
# 3                          el Barri Gòtic  41.380620   2.175170
# 4                          el Barri Gòtic  41.379780   2.176230
# ...                                   ...        ...        ...
# 11078                        el Poble Sec  41.372603   2.166521
# 11079            Sant Martí de Provençals  41.416420   2.195170
# 11080              la Dreta de l'Eixample  41.398464   2.173269
# 11081      la Nova Esquerra de l'Eixample  41.384940   2.145140
# 11082                  la Sagrada Família  41.404897   2.180792
#
#              room_type  price  ...  calculated_host_listings_count  \
# 0      Entire home/apt  179.0  ...                              29
# 1      Entire home/apt  251.0  ...                               1
# 2      Entire home/apt  104.0  ...                               3
# 3      Entire home/apt  157.0  ...                               3
# 4      Entire home/apt  401.0  ...                               3
# ...                ...    ...  ...                             ...
# 11078  Entire home/apt  111.0  ...                               2
# 11079     Private room   74.0  ...                              24
# 11080     Private room   59.0  ...                               4
# 11081     Private room   68.0  ...                               2
# 11082  Entire home/apt  307.0  ...                               1
#
#        availability_365 number_of_reviews_ltm      license  \
# 0                   147                     5  HUTB-002062
# 1                     0                     8   HUTB005057
# 2                   107                    31  HUTB-001722
# 3                   327                    15       Exempt
# 4                   191                    34  HUTB-150671
# ...                 ...                   ...          ...
# 11078               140                     1  HUTB-011205
# 11079                82                     1  HUTB-748559
# 11080               340                     1       Exempt
# 11081               345                     1       Exempt
# 11082                51                     1  HUTB-003778
#
#        review_scores_rating        date  estimated_revenue_l365d bedrooms  \
# 0                      4.39  2013-05-27                   5370.0      3.0
# 1                      4.80  2011-03-15                  12048.0      3.0
# 2                      4.46  2011-07-17                  19344.0      2.0
# 3                      4.36  2010-07-10                  40035.0      1.0
# 4                      4.54  2010-10-03                 102255.0      4.0
# ...                     ...         ...                      ...      ...
# 11078                  5.00  2025-03-04                    666.0      1.0
# 11079                  4.00  2025-03-07                    444.0      1.0
# 11080                  5.00  2025-03-03                    354.0      1.0
# 11081                  5.00  2025-03-05                    408.0      1.0
# 11082                  5.00  2025-03-05                   1842.0      2.0
#
#        beds bathrooms
# 0       6.0       2.0
# 1       4.0       2.0
# 2       3.0       1.5
# 3       1.0       1.0
# 4       6.0       3.0
# ...     ...       ...
# 11078   2.0       1.0
# 11079   1.0       1.0
# 11080   1.0       1.0
# 11081   1.0       1.0
# 11082   2.0       2.0
#
# [11083 rows x 24 columns]

# %%
# Check for missing values in key columns
print("Missing Values:")
print(overall_listings[['estimated_revenue_l365d', 'bedrooms', 'beds', 'bathrooms']].isnull().sum())
# Out:
# Missing Values:
# estimated_revenue_l365d    1494
# bedrooms                    627
# beds                       1500
# bathrooms                  1493
# dtype: int64

# %%
overall_listings.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  11083.000000  11083.000000  11083.000000    11083.000000
# mean      41.391898      2.167178    165.821258        7.618244
# std        0.013670      0.017107    253.396585       18.583971
# min       41.350673      2.085593     14.000000        1.000000
# 25%       41.381040      2.157475     91.000000        1.000000
# 50%       41.390140      2.167870    123.000000        2.000000
# 75%       41.401212      2.176889    188.000000        4.000000
# max       41.455810      2.221330  10000.000000      865.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       11083.000000       11083.000000                    11083.000000
# mean           81.861680           1.791411                       28.181269
# std           127.637498           2.160469                       55.490753
# min             1.000000           0.010000                        1.000000
# 25%             7.000000           0.390000                        2.000000
# 50%            31.000000           1.300000                        7.000000
# 75%           105.000000           2.570000                       23.000000
# max          3091.000000          79.120000                      483.000000
#
#        availability_365  number_of_reviews_ltm  review_scores_rating  \
# count      11083.000000           11083.000000          11083.000000
# mean         170.831183              19.792295              4.603372
# std          125.118737              29.404745              0.442485
# min            0.000000               0.000000              1.000000
# 25%           34.000000               2.000000              4.480000
# 50%          189.000000              11.000000              4.690000
# 75%          284.000000              31.000000              4.880000
# max          365.000000            1239.000000              5.000000
#
#        estimated_revenue_l365d      bedrooms         beds    bathrooms
# count             9.589000e+03  10456.000000  9583.000000  9590.000000
# mean              2.041490e+04      1.839040     2.670458     1.369135
# std               2.587666e+04      1.113291     1.928088     0.654390
# min               0.000000e+00      0.000000     0.000000     0.000000
# 25%               3.780000e+03      1.000000     1.000000     1.000000
# 50%               1.344000e+04      2.000000     2.000000     1.000000
# 75%               3.009000e+04      2.000000     4.000000     2.000000
# max               1.050000e+06     12.000000    26.000000     9.000000

# %%
overall_listings['estimated_revenue_l365d'] = overall_listings['estimated_revenue_l365d'].fillna(overall_listings['estimated_revenue_l365d'].median())
overall_listings.dropna(subset=['bedrooms', 'beds', 'bathrooms'], inplace=True)

# %%
# Check for missing values in key columns
print("Missing Values:")
print(overall_listings[['estimated_revenue_l365d', 'bedrooms', 'beds', 'bathrooms']].isnull().sum())
# Out:
# Missing Values:
# estimated_revenue_l365d    0
# bedrooms                   0
# beds                       0
# bathrooms                  0
# dtype: int64

# %%
# Check for duplicate rows based on those columns
duplicates = overall_listings.duplicated(subset=['id', 'estimated_revenue_l365d', 'bedrooms', 'beds', 'bathrooms'])
print(f"\nDuplicate Rows in Key Columns: {duplicates.sum()}")
# Out:
# Duplicate Rows in Key Columns: 0

# %%
# Fixing duplicated column name
# Identify duplicated column names

cols = overall_listings.columns.tolist()
review_cols = [i for i, col in enumerate(cols) if col == 'number_of_reviews']
if len(review_cols) > 1:
    cols[review_cols[1]] = 'reviews_last_year'
overall_listings.columns = cols
print("Renamed second 'number_of_reviews' column to 'reviews_last_year'")
# Out:
# Renamed second 'number_of_reviews' column to 'reviews_last_year'

# %%
overall_listings.describe()
# Out:
#           latitude    longitude         price  minimum_nights  \
# count  9579.000000  9579.000000   9579.000000     9579.000000
# mean     41.391875     2.166936    173.418415        7.078505
# min      41.350673     2.085593     14.000000        1.000000
# 25%      41.381070     2.157160     82.000000        1.000000
# 50%      41.390308     2.167680    140.000000        2.000000
# 75%      41.401230     2.176590    201.000000        3.000000
# max      41.455810     2.221330  10000.000000      865.000000
# std       0.013559     0.017135    271.625238       15.982493
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count        9579.000000        9579.000000                     9579.000000
# mean           88.316526           1.938756                       30.567178
# min             1.000000           0.010000                        1.000000
# 25%             8.000000           0.510000                        2.000000
# 50%            37.000000           1.500000                        8.000000
# 75%           114.000000           2.710000                       26.000000
# max          3091.000000          79.120000                      483.000000
# std           132.403333           2.221875                       57.771422
#
#        yearly_availability  reviews_last_year       rating  \
# count          9579.000000        9579.000000  9579.000000
# mean            188.259944          21.804259     4.604065
# min               0.000000           0.000000     1.000000
# 25%              81.000000           3.000000     4.480000
# 50%             214.000000          14.000000     4.690000
# 75%             290.000000          33.000000     4.860000
# max             365.000000        1239.000000     5.000000
# std             118.269110          30.524735     0.426033
#
#                                 date  estimated_revenue     bedrooms  \
# count                           9579       9.579000e+03  9579.000000
# mean   2021-03-09 23:37:18.020670208       2.040966e+04     1.834116
# min              2010-07-10 00:00:00       0.000000e+00     0.000000
# 25%              2018-08-03 00:00:00       3.782000e+03     1.000000
# 50%              2022-06-08 00:00:00       1.345200e+04     2.000000
# 75%              2024-04-07 00:00:00       3.009000e+04     2.000000
# max              2025-03-09 00:00:00       1.050000e+06    12.000000
# std                              NaN       2.584629e+04     1.108982
#
#               beds    bathrooms
# count  9579.000000  9579.000000
# mean      2.671156     1.368828
# min       0.000000     0.000000
# 25%       1.000000     1.000000
# 50%       2.000000     1.000000
# 75%       4.000000     2.000000
# max      26.000000     9.000000
# std       1.928188     0.653502

# %% [markdown]
# # 5. Exploratory Data Analysis

# %%
overall_listings.describe()
# Out:
#           latitude    longitude         price  minimum_nights  \
# count  9579.000000  9579.000000   9579.000000     9579.000000
# mean     41.391875     2.166936    173.418415        7.078505
# min      41.350673     2.085593     14.000000        1.000000
# 25%      41.381070     2.157160     82.000000        1.000000
# 50%      41.390308     2.167680    140.000000        2.000000
# 75%      41.401230     2.176590    201.000000        3.000000
# max      41.455810     2.221330  10000.000000      865.000000
# std       0.013559     0.017135    271.625238       15.982493
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count        9579.000000        9579.000000                     9579.000000
# mean           88.316526           1.938756                       30.567178
# min             1.000000           0.010000                        1.000000
# 25%             8.000000           0.510000                        2.000000
# 50%            37.000000           1.500000                        8.000000
# 75%           114.000000           2.710000                       26.000000
# max          3091.000000          79.120000                      483.000000
# std           132.403333           2.221875                       57.771422
#
#        yearly_availability  number_of_reviews       rating  \
# count          9579.000000        9579.000000  9579.000000
# mean            188.259944          21.804259     4.604065
# min               0.000000           0.000000     1.000000
# 25%              81.000000           3.000000     4.480000
# 50%             214.000000          14.000000     4.690000
# 75%             290.000000          33.000000     4.860000
# max             365.000000        1239.000000     5.000000
# std             118.269110          30.524735     0.426033
#
#                                 date  estimated_revenue     bedrooms  \
# count                           9579       9.579000e+03  9579.000000
# mean   2021-03-09 23:37:18.020670208       2.040966e+04     1.834116
# min              2010-07-10 00:00:00       0.000000e+00     0.000000
# 25%              2018-08-03 00:00:00       3.782000e+03     1.000000
# 50%              2022-06-08 00:00:00       1.345200e+04     2.000000
# 75%              2024-04-07 00:00:00       3.009000e+04     2.000000
# max              2025-03-09 00:00:00       1.050000e+06    12.000000
# std                              NaN       2.584629e+04     1.108982
#
#               beds    bathrooms
# count  9579.000000  9579.000000
# mean      2.671156     1.368828
# min       0.000000     0.000000
# 25%       1.000000     1.000000
# 50%       2.000000     1.000000
# 75%       4.000000     2.000000
# max      26.000000     9.000000
# std       1.928188     0.653502

# %%
from datetime import timedelta
import matplotlib.pyplot as plt
import seaborn as sns

# Make sure date is in datetime format
overall_listings['date'] = pd.to_datetime(overall_listings['date'], errors='coerce')
latest_date = overall_listings['date'].max()
one_year_ago = latest_date - timedelta(days=365)
recent_data = overall_listings[overall_listings['date'] >= one_year_ago].copy()

# Plot: Price Distribution for the last 12 months
plt.figure(figsize=(8, 5))
sns.histplot(data=recent_data, x='price', bins=1000, color='teal')
plt.title('Price Distribution for Last 12 Months')
plt.xlabel('Price (€ per night)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Identifying Outliers**

# %%
Q1 = overall_listings['price'].quantile(0.25)
Q3 = overall_listings['price'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = overall_listings[(overall_listings['price'] < lower_bound) | (overall_listings['price'] > upper_bound)]
print(f"Lower Bound: {lower_bound:.2f}")
print(f"Upper Bound: {upper_bound:.2f}")
print(f"Number of outliers: {outliers.shape[0]}")
print(f"Total listings: {overall_listings.shape[0]}")
print(f"Percentage of outliers: {(outliers.shape[0] / overall_listings.shape[0]) * 100:.2f}%")
# Out:
# Lower Bound: -96.50
# Upper Bound: 379.50
# Number of outliers: 466
# Total listings: 9579
# Percentage of outliers: 4.86%

# %%
# Optional: Preview outliers
outliers[['id', 'price', 'neighbourhood', 'room_type']].head()
# Out:
#         id  price                                 neighbourhood  \
# 4    34981  401.0                                el Barri Gòtic
# 18  112538  386.0                            la Sagrada Família
# 20  118228  386.0                            la Sagrada Família
# 23  138055  449.0                            la Sagrada Família
# 33  198958  395.0  Diagonal Mar i el Front Marítim del Poblenou
#
#           room_type
# 4   Entire home/apt
# 18  Entire home/apt
# 20  Entire home/apt
# 23  Entire home/apt
# 33  Entire home/apt

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 4))
sns.boxplot(data=overall_listings, x='price', color='salmon')
plt.title('Boxplot of Listing Prices')
plt.xlabel('Price (€)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Attention:**
# Filtered outlier pricing range to nothing greater than €850 to reduce skew and improve visualization accuracy

# %% [markdown]
# **Price distribution**

# %%
airbnb_summary_capped = overall_listings.copy()
airbnb_summary_capped['price_capped'] = airbnb_summary_capped['price'].clip(upper=850)

airbnb_summary_capped['date'] = pd.to_datetime(airbnb_summary_capped['date'], errors='coerce')
latest_date = airbnb_summary_capped['date'].max()
one_year_ago = latest_date - timedelta(days=365)
recent_data_capped = airbnb_summary_capped[airbnb_summary_capped['date'] >= one_year_ago].copy()


plt.figure(figsize=(8, 5))
sns.histplot(data=recent_data_capped, x='price_capped', bins=100, color='teal')
plt.title('Price Distribution for Last 12 Months')
plt.xlabel('Price (€ per night)')
plt.ylabel('Frequency')
plt.xlim(0, 850)
plt.tight_layout()
plt.show()

# %%
airbnb_summary_capped = overall_listings.copy()
airbnb_summary_capped['price_capped'] = airbnb_summary_capped['price'].clip(upper=850)

airbnb_summary_capped['date'] = pd.to_datetime(airbnb_summary_capped['date'], errors='coerce')
latest_date = airbnb_summary_capped['date'].max()
one_year_ago = latest_date - timedelta(days=365)
recent_data_capped = airbnb_summary_capped[airbnb_summary_capped['date'] >= one_year_ago].copy()


plt.figure(figsize=(8, 5))
sns.histplot(data=recent_data_capped, x='price_capped', bins=100, color='teal')
plt.title('Price Distribution for Last 12 Months')
plt.xlabel('Price (€ per night)')
plt.ylabel('Frequency')
plt.xlim(0, 850)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
#
# The average nightly price for Airbnb listings over the past 12 months is approximately €132, with most listings priced between €63 and €153. The median price sits at €106, indicating a slight right-skew. While the minimum price is €14, the upper cap of €850 reflects a small number of high-end or luxury listings that significantly stretch the pricing spectrum. Overall, the distribution suggests a healthy mid-market segment with a few premium outliers.

# %% [markdown]
# **Availability stats**

# %%
# Exploring Price distribuion by availability throughout the year 
plt.figure(figsize=(6, 3))
sns.histplot(data=airbnb_summary_capped, x='yearly_availability')
plt.title('Distribuition of Availability Over Time')
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Insight:**
# The availability of Airbnb listings in Barcelona shows significant variation. On average, listings are available for approximately 171 days per year, with half of all listings open for bookings more than six months annually. However, the wide standard deviation (~125 days) suggests a split between full-time and highly seasonal listings. Notably, some listings report zero availability — indicating they may be inactive or paused — while others remain open year-round, highlighting a diverse hosting landscape across the city.

# %%
# Grouping price by neighbourhood
airbnb_summary_capped.groupby(by='neighbourhood_group')['price_capped'].mean()
# Out:
# neighbourhood_group
# Ciutat Vella           130.096412
# Eixample               185.626737
# Gràcia                 159.710699
# Horta-Guinardó         118.469965
# Les Corts              145.681416
# Nou Barris              84.549020
# Sant Andreu            103.328671
# Sant Martí             152.520302
# Sants-Montjuïc         138.612489
# Sarrià-Sant Gervasi    148.079002
# Name: price_capped, dtype: float64

# %% [markdown]
# **Insight:**
#
# Average prices vary significantly across Barcelona's neighborhoods. Eixample and Sant Martí lead with the highest average nightly rates (€186 and €153), suggesting strong demand or more upscale listings. In contrast, Nou Barris is the most affordable at €85, highlighting price diversity across the city and potential opportunities for budget-conscious travelers.

# %% [markdown]
# **Neighborhood price comparisons**

# %%
# Price dependency on neighbourhood and room type
plt.figure(figsize=(12, 6))
sns.barplot(
    data=airbnb_summary_capped, 
    x='neighbourhood_group', 
    y='price_capped', 
    hue='room_type',
    errorbar='sd'
)
plt.title('Average Price by Neighbourhood and Room Type')
plt.xlabel('Neighbourhood')
plt.ylabel('Average Nightly Price (€)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
price_summary_by_group = airbnb_summary_capped.groupby(['neighbourhood_group', 'room_type'])['price_capped'].mean().round(2)
print("\nAverage Price (€) by Neighbourhood and Room Type:")
print(price_summary_by_group)
# Out:
# Average Price (€) by Neighbourhood and Room Type:
# neighbourhood_group  room_type
# Ciutat Vella         Entire home/apt    156.85
#                      Hotel room         246.95
#                      Private room        97.68
#                      Shared room         42.00
# Eixample             Entire home/apt    215.49
#                      Hotel room         138.73
#                      Private room       105.53
#                      Shared room        123.37
# Gràcia               Entire home/apt    179.53
#                      Hotel room         160.33
#                      Private room        90.90
#                      Shared room         67.14
# Horta-Guinardó       Entire home/apt    159.57
#                      Private room        67.98
# Les Corts            Entire home/apt    163.37
#                      Private room        81.78
# Nou Barris           Entire home/apt    143.56
#                      Private room        65.39
# Sant Andreu          Entire home/apt    150.14
#                      Private room        63.63
#                      Shared room         31.00
# Sant Martí           Entire home/apt    178.00
#                      Hotel room         170.00
#                      Private room        92.58
#                      Shared room         42.38
# Sants-Montjuïc       Entire home/apt    167.47
#                      Hotel room         137.00
#                      Private room        78.48
#                      Shared room         39.75
# Sarrià-Sant Gervasi  Entire home/apt    166.37
#                      Private room        91.18
# Name: price_capped, dtype: float64

# %% [markdown]
# **Insight:**
#
# Across Barcelona, entire homes consistently command the highest average prices, particularly in Eixample (€215.49) and Sant Martí (€178.00), signaling strong demand for full-property rentals in central and beachfront areas. Private rooms are more affordable, averaging around €90–€105 in popular neighborhoods like Ciutat Vella and Eixample. Shared rooms are the least expensive, often under €50, with some as low as €31 in Sant Andreu. Notably, hotel rooms show price variability, reaching €246.95 in Ciutat Vella but only €138.73 in Eixample — highlighting different accommodation strategies across districts.

# %% [markdown]
# **Price vs guest rating**

# %%
# Remove duplicate column names
airbnb_summary_capped = airbnb_summary_capped.loc[:, ~airbnb_summary_capped.columns.duplicated()]

# %%
# Filter dataset for listings with < 1600 reviews due to outliers
filtered_reviews = airbnb_summary_capped[airbnb_summary_capped['number_of_reviews'] < 1600]

# Plot: Number of Reviews vs Price
plt.figure(figsize=(8, 5))
plt.title("Number of Reviews vs Price by Neighbourhood")
sns.scatterplot(
    data=filtered_reviews,
    x='number_of_reviews',
    y='price_capped',
    hue='neighbourhood_group',
    alpha=0.6
)
plt.xlabel('Number of Reviews')
plt.ylabel('Price (€ per night)')
plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary Statistics (Filtered Listings):")
print("Number of Reviews:")
print(filtered_reviews['number_of_reviews'].describe())
print("\nPrice (Capped at €850):")
print(filtered_reviews['price_capped'].describe())
# Out:
# Summary Statistics (Filtered Listings):
# Number of Reviews:
# count    9578.000000
# mean       88.003028
# std       128.805828
# min         1.000000
# 25%         8.000000
# 50%        37.000000
# 75%       114.000000
# max      1564.000000
# Name: number_of_reviews, dtype: float64
#
# Price (Capped at €850):
# count    9578.000000
# mean      163.962414
# std       126.520473
# min        14.000000
# 25%        82.250000
# 50%       140.000000
# 75%       201.000000
# max       850.000000
# Name: price_capped, dtype: float64

# %% [markdown]
# **Insight:**
#
# Listings with fewer than 1600 reviews have a median nightly price of €140, with most falling between €82 and €201. The average review count is 88, though a wide range suggests both new and highly-reviewed listings are active. This distribution shows a healthy mix of listings in terms of visibility and pricing, with outliers already removed.
#
# **Recommendation**
#
# Focus pricing strategies around the median range (€140) to stay competitive while appealing to the largest segment of active listings. Encourage hosts with lower review counts to improve visibility through pricing incentives or promotional listings, as high engagement isn’t limited to top-reviewed properties.

# %% [markdown]
#  **Room Type Breakdown**

# %%
# Count and average price by room type
room_type_summary = airbnb_summary_capped.groupby('room_type')['price_capped'].agg(['count', 'mean']).round(2)
print(room_type_summary)
# Out:
#                  count    mean
# room_type
# Entire home/apt   7419  187.93
# Hotel room          98  164.47
# Private room      3515   94.39
# Shared room         51   92.98

# %% [markdown]
# **Insight:**
#
# Entire homes are the most common listing type (7,419 listings) and also command the highest average price at €187.93 per night. In contrast, private and shared rooms are more budget-friendly, averaging under €95, with significantly fewer hotel room and shared room listings available.

# %% [markdown]
# **Estimated Revenue Leader (Room Type)**

# %%
# Group by room_type using actual estimated revenue
revenue_by_room_type = airbnb_summary_capped.groupby('room_type')['estimated_revenue'].mean().round(2)
print(revenue_by_room_type)
# Out:
# room_type
# Entire home/apt    25084.79
# Hotel room          9337.91
# Private room        8848.23
# Shared room         7316.60
# Name: estimated_revenue, dtype: float64

# %%
# Extract month from the review date
airbnb_summary_capped['month'] = pd.to_datetime(airbnb_summary_capped['date'], errors='coerce').dt.to_period('M')
airbnb_summary_capped[['id', 'room_type', 'price_capped', 'yearly_availability', 'estimated_revenue']].head()
# Out:
#       id        room_type  price_capped  yearly_availability  \
# 0  18674  Entire home/apt         179.0                  147
# 1  23197  Entire home/apt         251.0                    0
# 2  32711  Entire home/apt         104.0                  107
# 3  34241  Entire home/apt         157.0                  327
# 4  34981  Entire home/apt         401.0                  191
#
#    estimated_revenue
# 0             5370.0
# 1            12048.0
# 2            19344.0
# 3            40035.0
# 4           102255.0

# %% [markdown]
# **Insight:**
#
# Entire home/apartment listings generate the highest estimated annual revenue (€25,085 on average), significantly outperforming other room types. Hotel rooms, private rooms, and shared rooms follow with decreasing revenue potential, averaging between €7,300 and €9,300.
#
# **Recommendation:**
#
# To maximize revenue, prioritize onboarding and support for entire home listings, particularly those with higher availability. Encourage hosts of private and shared rooms to optimize availability and pricing, as they show consistent but lower revenue performance.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta

# Ensure 'date' column is datetime
airbnb_summary_capped['date'] = pd.to_datetime(airbnb_summary_capped['date'], errors='coerce')

# Filter for last 12 months
latest_date = airbnb_summary_capped['date'].max()
one_year_ago = latest_date - timedelta(days=365)
recent_data = airbnb_summary_capped[airbnb_summary_capped['date'] >= one_year_ago].copy()

# Extract month and group by it
recent_data['month'] = recent_data['date'].dt.to_period('M')
monthly_trend = (
    recent_data
    .groupby('month')['price_capped']
    .mean()
    .reset_index()
)
monthly_trend['month'] = monthly_trend['month'].astype(str)

# Plot the seasonal trend (clean version)
plt.figure(figsize=(10, 5))
sns.lineplot(data=monthly_trend, x='month', y='price_capped', marker='o', color='teal')
plt.title('Average Price per Month (Last 12 Months)')
plt.xlabel('Month')
plt.ylabel('Average Nightly Price (€)')
plt.xticks(rotation=45)
plt.grid(False)               
plt.legend([],[], frameon=False)  
plt.tight_layout()
plt.show()

# %%
# Print seasonal summary
print("\nSeasonal Price Summary (Last 12 Months):")
print("Highest Avg. Price Month:", monthly_trend.loc[monthly_trend['price_capped'].idxmax()].to_dict())
print("Lowest Avg. Price Month:", monthly_trend.loc[monthly_trend['price_capped'].idxmin()].to_dict())
# Out:
# Seasonal Price Summary (Last 12 Months):
# Highest Avg. Price Month: {'month': '2024-03', 'price_capped': 163.2173913043478}
# Lowest Avg. Price Month: {'month': '2024-10', 'price_capped': 109.41810344827586}

# %%
# Ensure 'date' is datetime and extract month
airbnb_summary_capped['date'] = pd.to_datetime(airbnb_summary_capped['date'], errors='coerce')
airbnb_summary_capped['month'] = airbnb_summary_capped['date'].dt.to_period('M')

# Group by month
monthly_trend = (
    airbnb_summary_capped
    .groupby('month')['price_capped']
    .mean()
    .reset_index()
)
monthly_trend['month'] = monthly_trend['month'].astype(str)

# Plot with simplified x-axis
plt.figure(figsize=(10, 5))
sns.lineplot(data=monthly_trend, x='month', y='price_capped', marker='o', color='teal')
plt.title('Average Price per Month (All Time)')
plt.xlabel('Month')
plt.ylabel('Average Nightly Price (€)')

# Show fewer ticks — every 6th label
plt.xticks(ticks=range(0, len(monthly_trend), 6), 
           labels=monthly_trend['month'].iloc[::6], 
           rotation=45)

plt.grid(False)
plt.legend([], [], frameon=False)
plt.tight_layout()
plt.show()

# %%
# Print seasonal price summary (all time)
print("\nSeasonal Price Summary (All Time):")
print("Highest Avg. Price Month:", monthly_trend.loc[monthly_trend['price_capped'].idxmax()].to_dict())
print("Lowest Avg. Price Month:", monthly_trend.loc[monthly_trend['price_capped'].idxmin()].to_dict())
# Out:
# Seasonal Price Summary (All Time):
# Highest Avg. Price Month: {'month': '2010-10', 'price_capped': 401.0}
# Lowest Avg. Price Month: {'month': '2011-07', 'price_capped': 104.0}

# %% [markdown]
# **Insight:**
#
# The highest average nightly price occurred in March 2024 (€163), while the lowest was in October 2024 (€109). This suggests that spring may offer stronger earning potential than early autumn, highlighting an opportunity for seasonal pricing adjustments to align with market demand.
#
# Over the full time span, historical anomalies like October 2010 (€401) and July 2011 (€104) highlight extreme fluctuations, possibly due to sparse or skewed early data. This suggests recent pricing patterns are more reliable for decision-making.

# %% [markdown]
# # Overall Findings and Recommendations
#
# **Findings:**
#
# The analysis of Airbnb listings in Barcelona shows a broad pricing range, with most listings priced between **€90 and €190 per night.** While private and shared rooms remain affordable, they generate less revenue compared to entire homes. On average, **entire apartments earn over €25,000 annually,** making them the most profitable segment.
#
# Neighborhood-level analysis shows **Eixample and Sant Martí command the highest prices,** while Nou Barris and Sant Andreu remain budget-friendly. Guest ratings are consistently high, and availability varies, indicating a mix of part-time and full-time rentals. Seasonally, **March** tends to bring the **highest prices,** while **October sees a dip;** a trend consistent with recent booking behavior.
#
# **Recommendations for Javier:**
#
# To support host success, focus efforts on expanding entire home listings in top-performing areas and **educating hosts of private/shared rooms** on how to optimize pricing and availability. The 'estimated_revenue' metric provides Javier with a reliable baseline to identify which room types and areas yield the highest returns.
#
# Additionally, leveraging seasonal pricing trends can help Javier guide hosts on when to adjust availability and pricing particularly promoting listings more aggressively during peak months and re-strategizing in slower periods like early autumn.
